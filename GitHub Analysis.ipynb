# %% [markdown]
# # Parameters
# * measure for TDD
#     * travis CI (used or not)
#     * test files (no of lines in test no of source code lines)
# * measure
#     * issues (issue freq)
#     * history (commit freq)

# %% [markdown]
# ## API

# %%
import requests
data=requests.get('https://api.github.com/users').json()
print(data)
# Out:
# [{'login': 'mojombo', 'id': 1, 'node_id': 'MDQ6VXNlcjE=', 'avatar_url': 'https://avatars0.githubusercontent.com/u/1?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/mojombo', 'html_url': 'https://github.com/mojombo', 'followers_url': 'https://api.github.com/users/mojombo/followers', 'following_url': 'https://api.github.com/users/mojombo/following{/other_user}', 'gists_url': 'https://api.github.com/users/mojombo/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/mojombo/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/mojombo/subscriptions', 'organizations_url': 'https://api.github.com/users/mojombo/orgs', 'repos_url': 'https://api.github.com/users/mojombo/repos', 'events_url': 'https://api.github.com/users/mojombo/events{/privacy}', 'received_events_url': 'https://api.github.com/users/mojombo/received_events', 'type': 'User', 'site_admin': False}, {'login': 'defunkt', 'id': 2, 'node_id': 'MDQ6VXNlcjI=', 'avatar_url': 'https://avatar
# ...

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize']=(10.0,10.0)
import math

# %%
data=pd.read_csv('travistorrent_28_8_2015.csv')
print(data.shape)
data.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (42,47) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# (2372655, 56)
#                                      commit               project_name  is_pr  \
# 0  ce412eb65893a8c0a1a9e98af7a3440b81ea0e75  47deg/appsly-android-rest  False
# 1  132efa7e2179bbd91e15e43c78d92075f7881835  47deg/appsly-android-rest  False
# 2  132efa7e2179bbd91e15e43c78d92075f7881835  47deg/appsly-android-rest  False
# 3  132efa7e2179bbd91e15e43c78d92075f7881835  47deg/appsly-android-rest  False
# 4  132efa7e2179bbd91e15e43c78d92075f7881835  47deg/appsly-android-rest  False
#
#   merged_with  lang  branch first_commit_created_at  team_size  \
# 0         NaN  java  master     2013-01-17 08:29:33        NaN
# 1         NaN  java  master     2013-01-17 08:28:46        NaN
# ...

# %%
data1=pd.read_csv('travistorrent_8_2_2017.csv')
print(data1.shape)
data1.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (3,6,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# (3702595, 62)
#    tr_build_id gh_project_name  gh_is_pr gh_pr_created_at  gh_pull_req_num  \
# 0       106060     rails/rails     False              NaN              NaN
# 1       106060     rails/rails     False              NaN              NaN
# 2       106060     rails/rails     False              NaN              NaN
# 3       106060     rails/rails     False              NaN              NaN
# 4       106060     rails/rails     False              NaN              NaN
#
#   gh_lang git_merged_with  git_branch  gh_num_commits_in_push  \
# 0    ruby             NaN  3-1-stable                     NaN
# 1    ruby             NaN  3-1-stable                     NaN
# 2    ruby             NaN  3-1-stable                     NaN
# ...

# %%
data1.head(10)
# Out:
#    tr_build_id gh_project_name  gh_is_pr gh_pr_created_at  gh_pull_req_num  \
# 0       106060     rails/rails     False              NaN              NaN
# 1       106060     rails/rails     False              NaN              NaN
# 2       106060     rails/rails     False              NaN              NaN
# 3       106060     rails/rails     False              NaN              NaN
# 4       106060     rails/rails     False              NaN              NaN
# 5       106060     rails/rails     False              NaN              NaN
# 6       106060     rails/rails     False              NaN              NaN
# 7       106060     rails/rails     False              NaN              NaN
# 8       106060     rails/rails     False              NaN              NaN
# 9       106060     rails/rails     False              NaN              NaN
#
#   gh_lang git_merged_with  git_branch  gh_num_commits_in_push  \
# 0    ruby             NaN  3-1-stable                     NaN
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2372655 entries, 0 to 2372654
# Data columns (total 56 columns):
# commit                      object
# project_name                object
# is_pr                       bool
# merged_with                 object
# lang                        object
# branch                      object
# first_commit_created_at     object
# team_size                   float64
# commits                     object
# num_commits                 int64
# num_issue_comments          int64
# num_commit_comments         int64
# num_pr_comments             int64
# committers                  float64
# src_churn                   float64
# test_churn                  float64
# files_added                 float64
# files_deleted               float64
# files_modified              float64
# tests_added                 float64
# tests_deleted               float64
# src_files                   float64
# doc_files                   float64
# ...

# %%
print(len(data.index))
# Out:
# 2372655

# %% [markdown]
# ## Data Wrangling

# %%
data.isnull().sum()
# Out:
# commit                            0
# project_name                      0
# is_pr                             0
# merged_with                 1892488
# lang                              0
# branch                           10
# first_commit_created_at           0
# team_size                   2372655
# commits                           0
# num_commits                       0
# num_issue_comments                0
# num_commit_comments               0
# num_pr_comments                   0
# committers                  2372655
# src_churn                   2372655
# test_churn                  2372655
# files_added                 2372655
# files_deleted               2372655
# files_modified              2372655
# tests_added                 2372655
# tests_deleted               2372655
# src_files                   2372655
# doc_files                   2372655
# other_files                 2372655
# commits_on_files_touched    2372655
# sloc                        2372655
# ...

# %%
data1.drop(columns=['tr_build_id','tr_job_id','tr_build_number','gh_pr_created_at','gh_pull_req_num','gh_lang','git_merged_with','git_branch','gh_commits_in_push','git_prev_commit_resolution_status','git_prev_built_commit','tr_prev_build','gh_first_commit_created_at','gh_team_size','git_all_built_commits','git_num_all_built_commits','git_trigger_commit','tr_virtual_merged_into','tr_original_commit','gh_num_commit_comments','gh_num_pr_comments','gh_diff_other_files','gh_num_commits_on_files_touched','gh_by_core_team_member','gh_description_complexity','gh_pushed_at','gh_build_started_at','tr_jobs','tr_log_lan','tr_log_setup_time','tr_log_analyzer','tr_log_frameworks','tr_log_buildduration'],inplace=True)

# %%
data1.drop(columns=['gh_num_commits_in_push','gh_num_issue_comments','git_diff_src_churn','gh_diff_files_added','gh_diff_files_deleted','gh_diff_files_modified','gh_diff_tests_added','gh_diff_tests_deleted','gh_diff_src_files','gh_diff_doc_files'])

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
data1.head(100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4de6c3280da3> in <module>
# ----> 1 pd.set_option('display.max_columns', None)
#       2 pd.set_option('display.max_rows', None)
#       3 data1.head(100)
#
# NameError: name 'pd' is not defined

# %%
data1.isnull().sum()
# Out:
# gh_project_name                    0
# gh_is_pr                           0
# gh_num_commits_in_push        416618
# gh_num_issue_comments        1766493
# git_diff_src_churn                 0
# git_diff_test_churn                0
# gh_diff_files_added                0
# gh_diff_files_deleted              0
# gh_diff_files_modified             0
# gh_diff_tests_added                0
# gh_diff_tests_deleted              0
# gh_diff_src_files                  0
# gh_diff_doc_files                  0
# gh_sloc                            0
# gh_test_lines_per_kloc             0
# gh_test_cases_per_kloc             0
# gh_asserts_cases_per_kloc          0
# tr_status                          0
# tr_duration                     1266
# tr_log_status                      0
# tr_log_bool_tests_ran              0
# tr_log_bool_tests_failed      201011
# tr_log_num_tests_ok           233048
# tr_log_num_tests_failed       205846
# tr_log_num_tests_run          306382
# ...

# %%
data1.drop_duplicates(keep=False,inplace=True)

# %% [markdown]
# ## Analysis

# %%
sns.countplot(x="gh_is_pr",data=data1)

# %%
d=data1.loc[:,('gh_project_name','gh_is_pr','tr_status','gh_sloc','gh_test_lines_per_kloc','gh_test_cases_per_kloc')]

# %%
d.drop_duplicates(keep=False,inplace=True)

# %%
d.isnull().sum()
# Out:
# gh_project_name           0
# gh_is_pr                  0
# tr_status                 0
# gh_sloc                   0
# gh_test_lines_per_kloc    0
# gh_test_cases_per_kloc    0
# dtype: int64

# %%
d.head(10)
# Out:
#              gh_project_name  gh_is_pr tr_status  gh_sloc  \
# 94            saberma/shopqi     False    failed     7093
# 144           saberma/shopqi     False    failed     7092
# 276           saberma/shopqi     False    passed     7096
# 725            errbit/errbit     False    passed     1309
# 757   matschaffer/knife-solo     False    failed      443
# 773     plataformatec/devise     False    passed     2890
# 1038       rubinius/rubinius     False    failed   164267
# 1234         radiant/radiant     False    passed    10548
# 1502          saberma/shopqi     False    passed     7099
# 1509          saberma/shopqi     False    passed     7099
#
#       gh_test_lines_per_kloc  gh_test_cases_per_kloc
# 94                705.484280               55.265755
# 144               705.583756               55.273548
# 276               718.996618               55.524239
# 725              1393.430099              141.329259
# 757               361.173815               36.117381
# ...

# %%
sns.countplot(x="gh_is_pr",data=data1)
